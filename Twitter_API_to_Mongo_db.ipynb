# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikasi/Python-projects/blob/main/Twitter_API_to_Mongo_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 2.8 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Setting variables to be used below
maxTweets = 1000
# Creating list to append tweet data to
tweets_list2 = []
# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('electric mobility since:2016-01-01 until:2022-05-10').get_items()):
  if i>maxTweets:
    break
  tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.username])
# Out:
# <ipython-input-4-d78a38ed3ca3>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.username])
# <ipython-input-4-d78a38ed3ca3>:9: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.username])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-05-09 23:46:38+00:00  1523811716454301696
# 1    2022-05-09 22:51:28+00:00  1523797831165018112
# 2    2022-05-09 22:49:32+00:00  1523797344956813312
# 3    2022-05-09 22:39:06+00:00  1523794720345845761
# 4    2022-05-09 21:57:52+00:00  1523784344275460098
# ...                        ...                  ...
# 996  2022-04-28 14:09:20+00:00  1519680167572131841
# 997  2022-04-28 14:07:38+00:00  1519679738461270017
# 998  2022-04-28 13:51:34+00:00  1519675696217755648
# 999  2022-04-28 13:39:15+00:00  1519672594437488640
# 1000 2022-04-28 13:29:16+00:00  1519670081411633153
#
#                                                    Text         Username
# 0     Barbados won two awards at the Caribbean Renew...   EnergyBarbados
# 1     😎The BMW virtual world is an education and tho...      HaiqaKhilji
# 2     Which is why I'm psyched to share the news of ...     adambrowning
# ...

# %%
from pymongo import MongoClient

# %%
KARTHIKASI= MongoClient("mongodb://KARTHIKASI:wData1212@ac-w3rgwgl-shard-00-00.sua4tju.mongodb.net:27017,ac-w3rgwgl-shard-00-01.sua4tju.mongodb.net:27017,ac-w3rgwgl-shard-00-02.sua4tju.mongodb.net:27017/?ssl=true&replicaSet=atlas-ir5kqg-shard-0&authSource=admin&retryWrites=true&w=majority")
db = KARTHIKASI["Tweets"]
collection=db["datas"]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['ac-w3rgwgl-shard-00-02.sua4tju.mongodb.net:27017', 'ac-w3rgwgl-shard-00-01.sua4tju.mongodb.net:27017', 'ac-w3rgwgl-shard-00-00.sua4tju.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-ir5kqg-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'Tweets'), 'datas')

# %%
dta=tweets_df2.to_dict("records")

# %%
dta
# Out:
# [{'Datetime': Timestamp('2022-05-09 23:46:38+0000', tz='UTC'),
#   'Tweet Id': 1523811716454301696,
#   'Text': 'Barbados won two awards at the Caribbean Renewable Energy Forum: Best Energy Efficiency Project\xa0for the Energy Efficient Retrofit of Public Streetlights, and\xa0Best E-Mobility Project\xa0for the Introduction of Electric Mobility into Public Transportation.\nhttps://t.co/r6faFhO9nz',
#   'Username': 'EnergyBarbados'},
#  {'Datetime': Timestamp('2022-05-09 22:51:28+0000', tz='UTC'),
#   'Tweet Id': 1523797831165018112,
#   'Text': '😎The BMW virtual world is an education and thought leadership platform, creating an engaging way to learn about “electric mobility, urban mobility, and sustainability.”',
#   'Username': 'HaiqaKhilji'},
#  {'Datetime': Timestamp('2022-05-09 22:49:32+0000', tz='UTC'),
#   'Tweet Id': 1523797344956813312,
# ...

# %%
collection.insert_many(dta)

# %%
#checking our data is stored in mongo db database by fetching the data

# %%
KARTHIKASI= MongoClient("mongodb://KARTHIKASI:wData1212@ac-w3rgwgl-shard-00-00.sua4tju.mongodb.net:27017,ac-w3rgwgl-shard-00-01.sua4tju.mongodb.net:27017,ac-w3rgwgl-shard-00-02.sua4tju.mongodb.net:27017/?ssl=true&replicaSet=atlas-ir5kqg-shard-0&authSource=admin&retryWrites=true&w=majority")
db = KARTHIKASI["Tweets"]
col=db["datas"]
X=col.find_one()
print(X)
#for data in X: for fetching all data 
 # print(data)
# Out:
# {'_id': ObjectId('6409f61f3df0941cbf772609'), 'Datetime': datetime.datetime(2022, 5, 9, 23, 46, 38), 'Tweet Id': 1523811716454301696, 'Text': 'Barbados won two awards at the Caribbean Renewable Energy Forum: Best Energy Efficiency Project\xa0for the Energy Efficient Retrofit of Public Streetlights, and\xa0Best E-Mobility Project\xa0for the Introduction of Electric Mobility into Public Transportation.\nhttps://t.co/r6faFhO9nz', 'Username': 'EnergyBarbados'}
